# %%
from pyecharts.charts import HeatMap, Kline, Line, Bar, Scatter, Grid, Boxplot

# 虚假数据
x_data = ['Apple', 'Huawei', 'Xiaomi', 'Oppo', 'Vivo', 'Meizu']
y_data = [123, 153, 89, 107, 98, 23]


bar = (Bar()
       .add_xaxis(x_data)
       .add_yaxis('', y_data)
      )

bar.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="fdee55be0f794c3d9dd8e39c2a889fdf" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_fdee55be0f794c3d9dd8e39c2a889fdf = echarts.init(
#                     document.getElementById('fdee55be0f794c3d9dd8e39c2a889fdf'), 'white', {renderer: 'canvas'});
#                 var option_fdee55be0f794c3d9dd8e39c2a889fdf = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "bar",
#             "legendHoverLink": true,
#             "data": [
#                 123,
#                 153,
#                 89,
#                 107,
#                 98,
#                 23
#             ],
#             "showBackground": false,
#             "barMinHeight": 0,
#             "barCategoryGap": "20%",
#             "barGap": "30%",
#             "large": false,
#             "largeThreshold": 400,
#             "seriesLayoutBy": "column",
#             "datasetIndex": 0,
#             "clip": true,
#             "zlevel": 0,
#             "z": 2,
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 ""
#             ],
#             "selected": {
#                 "": true
#             }
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "showContent": true,
#         "alwaysShowContent": false,
#         "showDelay": 0,
#         "hideDelay": 100,
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0,
#         "padding": 5
#     },
#     "xAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "show": true,
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             },
#             "data": [
#                 "Apple",
#                 "Huawei",
#                 "Xiaomi",
#                 "Oppo",
#                 "Vivo",
#                 "Meizu"
#             ]
#         }
#     ],
#     "yAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "show": true,
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             }
#         }
#     ]
# };
#                 chart_fdee55be0f794c3d9dd8e39c2a889fdf.setOption(option_fdee55be0f794c3d9dd8e39c2a889fdf);
#         });
#     </script>

# %%
# 虚假数据
from pyecharts.charts import HeatMap, Kline, Line, Bar, Scatter, Grid, Boxplot
import random

x_data = ['Apple', 'Huawei', 'Xiaomi', 'Oppo', 'Vivo', 'Meizu']
y_data = [[random.randint(100, 200) for i in range(10)] for item in x_data]
print(x_data)
print(y_data)
Box = Boxplot()
Box.add_xaxis(x_data)
Box.add_yaxis("", Box.prepare_data(y_data))
Box.render_notebook()
# Out:
# ['Apple', 'Huawei', 'Xiaomi', 'Oppo', 'Vivo', 'Meizu']
# [[181, 198, 157, 118, 157, 184, 142, 184, 143, 172], [181, 147, 157, 126, 187, 167, 198, 141, 177, 185], [186, 154, 190, 151, 182, 187, 168, 172, 174, 118], [131, 107, 175, 126, 166, 126, 122, 142, 199, 200], [142, 150, 149, 155, 153, 107, 171, 191, 195, 162], [120, 180, 128, 195, 170, 142, 180, 108, 144, 150]]
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="3f80c69a047d49d8ac270cf4b6575806" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_3f80c69a047d49d8ac270cf4b6575806 = echarts.init(
#                     document.getElementById('3f80c69a047d49d8ac270cf4b6575806'), 'white', {renderer: 'canvas'});
#                 var option_3f80c69a047d49d8ac270cf4b6575806 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "boxplot",
#             "data": [
#                 [
#                     118,
#                     142.75,
#                     164.5,
#                     184.0,
#                     198
#                 ],
#                 [
#                     126,
#                     145.5,
#                     172.0,
#                     185.5,
#                     198
#                 ],
#                 [
#                     118,
#                     153.25,
#                     173.0,
#                     186.25,
#                     190
#                 ],
#                 [
#                     107,
#                     125.0,
#                     136.5,
#                     181.0,
#                     200
#                 ],
#                 [
#                     107,
#                     147.25,
#                     154.0,
#                     176.0,
#                     195
#                 ],
#                 [
#                     108,
#                     126.0,
#                     147.0,
#                     180.0,
#                     195
#                 ]
#             ],
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8
#             },
#             "markPoint": {
#                 "label": {
#                     "show": true,
#                     "position": "inside",
#                     "color": "#fff",
#                     "margin": 8
#                 }
#             },
#             "markLine": {
#                 "silent": false,
#                 "precision": 2,
#                 "label": {
#                     "show": true,
#                     "position": "top",
#                     "margin": 8
#                 }
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 ""
#             ],
#             "selected": {
#                 "": true
#             }
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "showContent": true,
#         "alwaysShowContent": false,
#         "showDelay": 0,
#         "hideDelay": 100,
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0,
#         "padding": 5
#     },
#     "xAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "show": true,
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             },
#             "data": [
#                 "Apple",
#                 "Huawei",
#                 "Xiaomi",
#                 "Oppo",
#                 "Vivo",
#                 "Meizu"
#             ]
#         }
#     ],
#     "yAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "show": true,
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             }
#         }
#     ]
# };
#                 chart_3f80c69a047d49d8ac270cf4b6575806.setOption(option_3f80c69a047d49d8ac270cf4b6575806);
#         });
#     </script>

# %%
# 虚假数据
from pyecharts.charts import HeatMap, Kline, Line, Bar, Scatter, Grid, Boxplot
from pyecharts import options as opts
import random
date_list = ['10月{}日'.format(i) for i in range(1, 32)]
data = [random.randint(10, 100) for _ in date_list]

line = (Line()
        .add_xaxis(date_list)
        .add_yaxis('', data)
        .set_series_opts(markarea_opts=opts.MarkAreaOpts(
            data=[
                opts.MarkAreaItem(name="十一黄金周", x=("10月1日", "10月7日")),
            ])
)
)

line.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="f9acf5b8420f4965b5f5c1463c8c804c" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_f9acf5b8420f4965b5f5c1463c8c804c = echarts.init(
#                     document.getElementById('f9acf5b8420f4965b5f5c1463c8c804c'), 'white', {renderer: 'canvas'});
#                 var option_f9acf5b8420f4965b5f5c1463c8c804c = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "line",
#             "connectNulls": false,
#             "symbolSize": 4,
#             "showSymbol": true,
#             "smooth": false,
#             "clip": true,
#             "step": false,
#             "data": [
#                 [
#                     "10\u67081\u65e5",
#                     31
#                 ],
#                 [
#                     "10\u67082\u65e5",
#                     37
#                 ],
#                 [
#                     "10\u67083\u65e5",
#                     46
#                 ],
#                 [
#                     "10\u67084\u65e5",
#                     10
#                 ],
#                 [
#                     "10\u67085\u65e5",
#                     53
#                 ],
#                 [
#                     "10\u67086\u65e5",
#                     74
#                 ],
#                 [
#                     "10\u67087\u65e5",
#                     98
#                 ],
#                 [
#                     "10\u67088\u65e5",
#                     70
#                 ],
#                 [
#                     "10\u67089\u65e5",
#                     57
#                 ],
#                 [
#                     "10\u670810\u65e5",
#                     39
#                 ],
#                 [
#                     "10\u670811\u65e5",
#                     11
#                 ],
#                 [
#                     "10\u670812\u65e5",
#                     72
#                 ],
#                 [
#                     "10\u670813\u65e5",
#                     59
#                 ],
#                 [
#                     "10\u670814\u65e5",
#                     83
#                 ],
#                 [
#                     "10\u670815\u65e5",
#                     37
#                 ],
#                 [
#                     "10\u670816\u65e5",
#                     100
#                 ],
#                 [
#                     "10\u670817\u65e5",
#                     88
#                 ],
#                 [
#                     "10\u670818\u65e5",
#                     99
#                 ],
#                 [
#                     "10\u670819\u65e5",
#                     37
#                 ],
#                 [
#                     "10\u670820\u65e5",
#                     78
#                 ],
#                 [
#                     "10\u670821\u65e5",
#                     66
#                 ],
#                 [
#                     "10\u670822\u65e5",
#                     79
#                 ],
#                 [
#                     "10\u670823\u65e5",
#                     79
#                 ],
#                 [
#                     "10\u670824\u65e5",
#                     80
#                 ],
#                 [
#                     "10\u670825\u65e5",
#                     88
#                 ],
#                 [
#                     "10\u670826\u65e5",
#                     49
#                 ],
#                 [
#                     "10\u670827\u65e5",
#                     47
#                 ],
#                 [
#                     "10\u670828\u65e5",
#                     73
#                 ],
#                 [
#                     "10\u670829\u65e5",
#                     64
#                 ],
#                 [
#                     "10\u670830\u65e5",
#                     21
#                 ],
#                 [
#                     "10\u670831\u65e5",
#                     63
#                 ]
#             ],
#             "hoverAnimation": true,
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8
#             },
#             "lineStyle": {
#                 "show": true,
#                 "width": 1,
#                 "opacity": 1,
#                 "curveness": 0,
#                 "type": "solid"
#             },
#             "areaStyle": {
#                 "opacity": 0
#             },
#             "zlevel": 0,
#             "z": 0,
#             "markArea": {
#                 "silent": false,
#                 "label": {
#                     "show": true,
#                     "position": "top",
#                     "margin": 8
#                 },
#                 "data": [
#                     [
#                         {
#                             "name": "\u5341\u4e00\u9ec4\u91d1\u5468",
#                             "xAxis": "10\u67081\u65e5"
#                         },
#                         {
#                             "xAxis": "10\u67087\u65e5"
#                         }
#                     ]
#                 ]
#             },
#             "rippleEffect": {
#                 "show": true,
#                 "brushType": "stroke",
#                 "scale": 2.5,
#                 "period": 4
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 ""
#             ],
#             "selected": {
#                 "": true
#             }
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "showContent": true,
#         "alwaysShowContent": false,
#         "showDelay": 0,
#         "hideDelay": 100,
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0,
#         "padding": 5
#     },
#     "xAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "show": true,
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             },
#             "data": [
#                 "10\u67081\u65e5",
#                 "10\u67082\u65e5",
#                 "10\u67083\u65e5",
#                 "10\u67084\u65e5",
#                 "10\u67085\u65e5",
#                 "10\u67086\u65e5",
#                 "10\u67087\u65e5",
#                 "10\u67088\u65e5",
#                 "10\u67089\u65e5",
#                 "10\u670810\u65e5",
#                 "10\u670811\u65e5",
#                 "10\u670812\u65e5",
#                 "10\u670813\u65e5",
#                 "10\u670814\u65e5",
#                 "10\u670815\u65e5",
#                 "10\u670816\u65e5",
#                 "10\u670817\u65e5",
#                 "10\u670818\u65e5",
#                 "10\u670819\u65e5",
#                 "10\u670820\u65e5",
#                 "10\u670821\u65e5",
#                 "10\u670822\u65e5",
#                 "10\u670823\u65e5",
#                 "10\u670824\u65e5",
#                 "10\u670825\u65e5",
#                 "10\u670826\u65e5",

# %%
import pyecharts.options as opts
from pyecharts.charts import Line

"""
Gallery 使用 pyecharts 1.1.0
参考地址: https://www.echartsjs.com/examples/editor.html?c=line-sections

目前无法实现的功能:

1、visualMap 暂时无法设置隐藏
"""

x_data = [
    "00:00",
    "01:15",
    "02:30",
    "03:45",
    "05:00",
    "06:15",
    "07:30",
    "08:45",
    "10:00",
    "11:15",
    "12:30",
    "13:45",
    "15:00",
    "16:15",
    "17:30",
    "18:45",
    "20:00",
    "21:15",
    "22:30",
    "23:45",
]
y_data = [
    300,
    280,
    250,
    260,
    270,
    300,
    550,
    500,
    400,
    390,
    380,
    390,
    400,
    500,
    600,
    750,
    800,
    700,
    600,
    400,
]

(
    Line(init_opts=opts.InitOpts(width="1600px", height="800px"))
    .add_xaxis(xaxis_data=x_data)
    .add_yaxis(
        series_name="用电量",
        y_axis=y_data,
        is_smooth=True,
        label_opts=opts.LabelOpts(is_show=False),
        linestyle_opts=opts.LineStyleOpts(width=2),
    )
    .set_global_opts(
        title_opts=opts.TitleOpts(title="一天用电量分布", subtitle="纯属虚构"),
        tooltip_opts=opts.TooltipOpts(trigger="axis", axis_pointer_type="cross"),
        xaxis_opts=opts.AxisOpts(boundary_gap=False),
        yaxis_opts=opts.AxisOpts(
            axislabel_opts=opts.LabelOpts(formatter="{value} W"),
            splitline_opts=opts.SplitLineOpts(is_show=True),
        ),
        visualmap_opts=opts.VisualMapOpts(
            is_piecewise=True,
            dimension=0,
            pieces=[
                {"lte": 6, "color": "green"},
                {"gt": 6, "lte": 8, "color": "red"},
                {"gt": 8, "lte": 14, "color": "green"},
                {"gt": 14, "lte": 17, "color": "red"},
                {"gt": 17, "color": "green"},
            ],
        ),
    )
    .set_series_opts(
        markarea_opts=opts.MarkAreaOpts(
            data=[
                opts.MarkAreaItem(name="", x=("07:30", "10:00"),y=(400,600)),
                opts.MarkAreaItem(name="晚高峰", x=("17:30", "21:15"),y=(300, 400)),
            ]
        )
    )
    .render_notebook()
)
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="5db60ef7383e4414a7c05513da05ce33" style="width:1600px; height:800px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_5db60ef7383e4414a7c05513da05ce33 = echarts.init(
#                     document.getElementById('5db60ef7383e4414a7c05513da05ce33'), 'white', {renderer: 'canvas'});
#                 var option_5db60ef7383e4414a7c05513da05ce33 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "line",
#             "name": "\u7528\u7535\u91cf",
#             "connectNulls": false,
#             "symbolSize": 4,
#             "showSymbol": true,
#             "smooth": true,
#             "clip": true,
#             "step": false,
#             "data": [
#                 [
#                     "00:00",
#                     300
#                 ],
#                 [
#                     "01:15",
#                     280
#                 ],
#                 [
#                     "02:30",
#                     250
#                 ],
#                 [
#                     "03:45",
#                     260
#                 ],
#                 [
#                     "05:00",
#                     270
#                 ],
#                 [
#                     "06:15",
#                     300
#                 ],
#                 [
#                     "07:30",
#                     550
#                 ],
#                 [
#                     "08:45",
#                     500
#                 ],
#                 [
#                     "10:00",
#                     400
#                 ],
#                 [
#                     "11:15",
#                     390
#                 ],
#                 [
#                     "12:30",
#                     380
#                 ],
#                 [
#                     "13:45",
#                     390
#                 ],
#                 [
#                     "15:00",
#                     400
#                 ],
#                 [
#                     "16:15",
#                     500
#                 ],
#                 [
#                     "17:30",
#                     600
#                 ],
#                 [
#                     "18:45",
#                     750
#                 ],
#                 [
#                     "20:00",
#                     800
#                 ],
#                 [
#                     "21:15",
#                     700
#                 ],
#                 [
#                     "22:30",
#                     600
#                 ],
#                 [
#                     "23:45",
#                     400
#                 ]
#             ],
#             "hoverAnimation": true,
#             "label": {
#                 "show": false,
#                 "position": "top",
#                 "margin": 8
#             },
#             "lineStyle": {
#                 "show": true,
#                 "width": 2,
#                 "opacity": 1,
#                 "curveness": 0,
#                 "type": "solid"
#             },
#             "areaStyle": {
#                 "opacity": 0
#             },
#             "zlevel": 0,
#             "z": 0,
#             "markArea": {
#                 "silent": false,
#                 "label": {
#                     "show": true,
#                     "position": "top",
#                     "margin": 8
#                 },
#                 "data": [
#                     [
#                         {
#                             "xAxis": "07:30",
#                             "yAxis": 400
#                         },
#                         {
#                             "xAxis": "10:00",
#                             "yAxis": 600
#                         }
#                     ],
#                     [
#                         {
#                             "name": "\u665a\u9ad8\u5cf0",
#                             "xAxis": "17:30",
#                             "yAxis": 300
#                         },
#                         {
#                             "xAxis": "21:15",
#                             "yAxis": 400
#                         }
#                     ]
#                 ]
#             },
#             "rippleEffect": {
#                 "show": true,
#                 "brushType": "stroke",
#                 "scale": 2.5,
#                 "period": 4
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "\u7528\u7535\u91cf"
#             ],
#             "selected": {
#                 "\u7528\u7535\u91cf": true
#             },
#             "show": true,
#             "padding": 5,
#             "itemGap": 10,
#             "itemWidth": 25,
#             "itemHeight": 14
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "axis",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "cross"
#         },
#         "showContent": true,
#         "alwaysShowContent": false,
#         "showDelay": 0,
#         "hideDelay": 100,
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0,
#         "padding": 5
#     },
#     "xAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "boundaryGap": false,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "show": true,
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             },
#             "data": [
#                 "00:00",
#                 "01:15",
#                 "02:30",
#                 "03:45",
#                 "05:00",
#                 "06:15",
#                 "07:30",
#                 "08:45",
#                 "10:00",
#                 "11:15",
#                 "12:30",
#                 "13:45",
#                 "15:00",
#                 "16:15",
#                 "17:30",
#                 "18:45",
#                 "20:00",
#                 "21:15",
#                 "22:30",
#                 "23:45"
#             ]
#         }
#     ],
#     "yAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "axisLabel": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8,
#                 "formatter": "{value} W"
#             },
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": true,
#                 "lineStyle": {
#                     "show": true,
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             }
#         }
#     ],
#     "title": [
#         {
#             "text": "\u4e00\u5929\u7528\u7535\u91cf\u5206\u5e03",
#             "subtext": "\u7eaf\u5c5e\u865a\u6784",
#             "padding": 5,
#             "itemGap": 10
#         }
#     ],
#     "visualMap": {
#         "show": true,
#         "type": "piecewise",
#         "min"
